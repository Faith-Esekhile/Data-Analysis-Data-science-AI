# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
import os

# %%
df=pd.read_csv("Assessment Data.csv")

# %%
df
# Out:
#                   Time       A       B       C      D       E        F  \
# 0      24/10/2022 0:00  37.383 -19.733  42.419  0.881  50.167  232.193
# 1      24/10/2022 0:10  38.533 -19.610  43.445  0.887  50.108  232.108
# 2      24/10/2022 0:11  37.971 -19.772  43.037  0.882  50.127  232.209
# 3      24/10/2022 0:14  34.070 -19.920  39.701  0.858  50.029  231.183
# 4      24/10/2022 0:15  34.697 -19.598  40.100  0.865  49.951  230.734
# ...                ...     ...     ...     ...    ...     ...      ...
# 47143              NaN     NaN     NaN     NaN    NaN     NaN      NaN
# 47144              NaN     NaN     NaN     NaN    NaN     NaN      NaN
# 47145              NaN     NaN     NaN     NaN    NaN     NaN      NaN
# 47146              NaN     NaN     NaN     NaN    NaN     NaN      NaN
# 47147              NaN     NaN     NaN     NaN    NaN     NaN      NaN
#
#              G       H        I  ...        W        X       Y       Z     AA  \
# ...

# %%
df.describe()
# Out:
#                   A             B             C             D             E  \
# count  46713.000000  46713.000000  46713.000000  46713.000000  46713.000000
# mean      62.235076     -7.914898     64.623946      0.947717     50.102639
# std       29.741302     12.594475     28.527942      0.042298      0.226898
# min       18.136000    -54.057000     27.264000      0.558000     43.568000
# 25%       38.708000    -16.483000     42.257000      0.918000     50.010000
# 50%       44.753000    -15.277000     47.612000      0.942000     50.117000
# 75%       88.190000      1.066000     88.313000      0.989000     50.226000
# max      134.924000     25.136000    136.486000      1.000000     51.179000
#
#                   F             G             H             I             J  \
# count  46713.000000  46713.000000  46713.000000  46713.000000  46713.000000
# mean     229.215963    397.031511     94.632405    230.467202    395.585939
# ...

# %%
df.shape
# Out:
# (47148, 33)

# %%
df.dtypes
# Out:
# Time     object
# A       float64
# B       float64
# C       float64
# D       float64
# E       float64
# F       float64
# G       float64
# H       float64
# I       float64
# J       float64
# K       float64
# L       float64
# M       float64
# N       float64
# O       float64
# P       float64
# Q       float64
# R       float64
# S       float64
# T       float64
# U       float64
# V       float64
# W       float64
# X       float64
# Y       float64
# Z       float64
# AA      float64
# BB      float64
# CC      float64
# DD      float64
# EE       object
# FF      float64
# dtype: object

# %%
df.EE.value_counts()
# Out:
# Grid    35677
# Gen3     6943
# Gen2     4093
# Name: EE, dtype: int64

# %% [markdown]
# The rate at which each power source is used

# %%
df.EE.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='EE'>

# %%
df["EE"].value_counts()
# Out:
# Grid    35677
# Gen3     6943
# Gen2     4093
# Name: EE, dtype: int64

# %%
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, fmt=".0f",cmap="YlOrRd_r")
plt.show()

# %%
df_copy=df
def get_min_max(colunm):
    MIN=df_copy.groupby(['EE'])[colunm].min()
    MAX=df_copy.groupby(['EE'])[colunm].max()
   
    df_new=pd.DataFrame([MIN,MAX])
    df_new.index=["min","max"]
    df_new.plot(kind="bar",stacked=False,figsize=(10,5))

# %%
get_min_max("A")

# %%
min_A=df.groupby(['EE'])["A"].min()
min_A
# Out:
# EE
# Gen2    33.959
# Gen3    18.136
# Grid    19.399
# Name: A, dtype: float64

# %%
max_A=df.groupby(['EE'])["A"].max()
max_A
# Out:
# EE
# Gen2    134.924
# Gen3    106.077
# Grid    132.896
# Name: A, dtype: float64

# %%
max_A=df.groupby(['EE'])["A"].max()
max_A
# Out:
# EE
# Gen2    134.924
# Gen3    106.077
# Grid    132.896
# Name: A, dtype: float64

# %%
get_min_max("B")

# %%
get_min_max("C")

# %%
get_min_max("D")

# %%
get_min_max("F")

# %%
df = df.drop(['F'], axis=1)

# %%
get_min_max("G")

# %%
df = df.drop(['G'], axis=1)

# %%
get_min_max("H")

# %%
get_min_max("I")

# %%
df = df.drop(['I'], axis=1)

# %%
get_min_max("J")

# %%
df = df.drop(['J'], axis=1)

# %%
get_min_max("K")

# %%
get_min_max("L")

# %%
get_min_max("M")

# %%
get_min_max("N")

# %%
get_min_max("O")

# %%
df = df.drop(['O'], axis=1)

# %%
get_min_max("P")

# %%
df = df.drop(['P'], axis=1)

# %%
get_min_max("Q")

# %%
df = df.drop(['Q'], axis=1)

# %%
get_min_max("R")

# %%
get_min_max("S")

# %%
get_min_max("T")

# %%
get_min_max("U")

# %%
get_min_max("V")

# %%
df = df.drop(['V'], axis=1)

# %%
get_min_max("W")

# %%
df = df.drop(['W'], axis=1)

# %%
get_min_max("X")

# %%
df = df.drop(['X'], axis=1)

# %%
get_min_max("Y")

# %%
get_min_max("Z")

# %%
get_min_max("AA")

# %%
get_min_max("BB")

# %%
get_min_max("CC")

# %%
get_min_max("DD")

# %%
df = df.drop(['DD'], axis=1)

# %%
df
# Out:
#                   Time       A       B       C      D       E       H       K  \
# 0      24/10/2022 0:00  37.383 -19.733  42.419  0.881  50.167  59.780  72.979
# 1      24/10/2022 0:10  38.533 -19.610  43.445  0.887  50.108  62.579  81.145
# 2      24/10/2022 0:11  37.971 -19.772  43.037  0.882  50.127  62.136  81.299
# 3      24/10/2022 0:14  34.070 -19.920  39.701  0.858  50.029  57.584  72.799
# 4      24/10/2022 0:15  34.697 -19.598  40.100  0.865  49.951  58.236  72.988
# ...                ...     ...     ...     ...    ...     ...     ...     ...
# 47143              NaN     NaN     NaN     NaN    NaN     NaN     NaN     NaN
# 47144              NaN     NaN     NaN     NaN    NaN     NaN     NaN     NaN
# 47145              NaN     NaN     NaN     NaN    NaN     NaN     NaN     NaN
# 47146              NaN     NaN     NaN     NaN    NaN     NaN     NaN     NaN
# 47147              NaN     NaN     NaN     NaN    NaN     NaN     NaN     NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Time    200
# A       435
# B       435
# C       435
# D       435
# E       435
# H       435
# K       435
# L       435
# M       435
# N       435
# R       435
# S       435
# T       435
# U       435
# Y       435
# Z       435
# AA      435
# BB      435
# CC      435
# EE      435
# FF      435
# dtype: int64

# %%
df["Time"] = pd.to_datetime(df["Time"],format="%d/%m/%Y %H:%M")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47148 entries, 0 to 47147
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    46948 non-null  datetime64[ns]
#  1   A       46713 non-null  float64
#  2   B       46713 non-null  float64
#  3   C       46713 non-null  float64
#  4   D       46713 non-null  float64
#  5   E       46713 non-null  float64
#  6   H       46713 non-null  float64
#  7   K       46713 non-null  float64
#  8   L       46713 non-null  float64
#  9   M       46713 non-null  float64
#  10  N       46713 non-null  float64
#  11  R       46713 non-null  float64
#  12  S       46713 non-null  float64
#  13  T       46713 non-null  float64
#  14  U       46713 non-null  float64
#  15  Y       46713 non-null  float64
#  16  Z       46713 non-null  float64
#  17  AA      46713 non-null  float64
#  18  BB      46713 non-null  float64
#  19  CC      46713 non-null  float64
# ...

# %%
time = df
time["Month"] = df["Time"].dt.month
time["Year"] = df["Time"].dt.year
time["Date"] = df["Time"].dt.date
time["Time"] = df["Time"].dt.time
time["Week"] = df["Time"].dt.week
time["Day"] = df["Time"].dt.day_name()
time = df.set_index('Time')
time.index = pd.to_datetime(time.index)
time.head(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-8008aaa4cf6d> in <module>
#       1 time = df
# ----> 2 time["Month"] = df["Time"].dt.month
#       3 time["Year"] = df["Time"].dt.year
#       4 time["Date"] = df["Time"].dt.date
#       5 time["Time"] = df["Time"].dt.time
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
df.dtypes
# Out:
# Time      object
# A        float64
# B        float64
# C        float64
# D        float64
# E        float64
# H        float64
# K        float64
# L        float64
# M        float64
# N        float64
# R        float64
# S        float64
# T        float64
# U        float64
# Y        float64
# Z        float64
# AA       float64
# BB       float64
# CC       float64
# EE        object
# FF       float64
# Month    float64
# Year     float64
# Date      object
# dtype: object

# %%
df.head(5)
# Out:
#        Time       A       B       C      D       E       H       K       L  \
# 0  00:00:00  37.383 -19.733  42.419  0.881  50.167  59.780  72.979  16.241
# 1  00:10:00  38.533 -19.610  43.445  0.887  50.108  62.579  81.145  17.473
# 2  00:11:00  37.971 -19.772  43.037  0.882  50.127  62.136  81.299  17.509
# 3  00:14:00  34.070 -19.920  39.701  0.858  50.029  57.584  72.799  15.106
# 4  00:15:00  34.697 -19.598  40.100  0.865  49.951  58.236  72.988  15.169
#
#        M  ...       Y       Z     AA      BB     CC    EE      FF  Month  \
# 0 -7.147  ...  51.618   9.745 -6.834  11.908  0.818  Grid  37.387   10.0
# 1 -6.803  ...  52.979  10.053 -6.933  12.218  0.823  Grid  38.537   10.0
# 2 -6.780  ...  52.894  10.029 -6.910  12.184  0.823  Grid  37.975   10.0
# 3 -7.131  ...  46.042   8.035 -6.818  10.543  0.762  Grid  34.073   10.0
# 4 -7.079  ...  45.852   8.045 -6.767  10.517  0.765  Grid  34.700   10.0
#
#      Year        Date
# 0  2022.0  2022-10-24
# 1  2022.0  2022-10-24
# ...

# %%
print(df.Year.unique(),"\n")
print("Total Number of Unique Year", df.Year.nunique(), "\n")
# Out:
# [2022.   nan]
#
# Total Number of Unique Year 1

# %%
print(df.Month.unique(),"\n")
print("Total Number of Unique Months", df.Month.nunique(), "\n")
# Out:
# [10.  9. nan]
#
# Total Number of Unique Months 2

# %%
df["Month"].value_counts()
# Out:
# 10.0    34128
# 9.0     12820
# Name: Month, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47148 entries, 0 to 47147
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    46948 non-null  object
#  1   A       46713 non-null  float64
#  2   B       46713 non-null  float64
#  3   C       46713 non-null  float64
#  4   D       46713 non-null  float64
#  5   E       46713 non-null  float64
#  6   H       46713 non-null  float64
#  7   K       46713 non-null  float64
#  8   L       46713 non-null  float64
#  9   M       46713 non-null  float64
#  10  N       46713 non-null  float64
#  11  R       46713 non-null  float64
#  12  S       46713 non-null  float64
#  13  T       46713 non-null  float64
#  14  U       46713 non-null  float64
#  15  Y       46713 non-null  float64
#  16  Z       46713 non-null  float64
#  17  AA      46713 non-null  float64
#  18  BB      46713 non-null  float64
#  19  CC      46713 non-null  float64
# ...

# %%
def line_plot(value):
    fig = plt.figure()
    ax1= fig.add_subplot()

    sns.lineplot(df[value],"FF",ci=None, hue="EE" ,data=df)

    plt.title("FF vs A sensor ")
    plt.xlabel(value)
    plt.ylabel("FF")
    plt.grid(True, alpha=1)
    plt.legend()

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(90)

# %%
line_plot("A")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("B")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("C")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("D")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("E")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("H")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("K")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("L")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("M")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("N")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("R")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("S")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("U")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("Y")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("Z")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("BB")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
line_plot("CC")
# Out:
# C:\Users\Faith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def G_plot(value):
    g = sns.FacetGrid(df, col='EE', hue='Month')
    g = g.map(sns.lineplot, value, 'FF', ci=None).add_legend()
#see if ff is affected by sensors using different grids

# %%
G_plot("A")

# %%
df = df.drop(['A'], axis=1)

# %%
G_plot("B")

# %%
df = df.drop(['B'], axis=1)

# %%
G_plot("C")

# %%
df = df.drop(['C'], axis=1)

# %%
G_plot("D")

# %%
df = df.drop(['D'], axis=1)

# %%
G_plot("E")

# %%
G_plot("H")

# %%
df = df.drop(['H'], axis=1)

# %%
G_plot("K")

# %%
df = df.drop(['K'], axis=1)

# %%
G_plot("L")

# %%
df = df.drop(['L'], axis=1)

# %%
G_plot("M")

# %%
df = df.drop(['M'], axis=1)

# %%
G_plot("N")

# %%
df = df.drop(['N'], axis=1)

# %%
G_plot("R")

# %%
df = df.drop(['R'], axis=1)

# %%
G_plot("S")

# %%
df = df.drop(['S'], axis=1)

# %%
G_plot("U")

# %%
G_plot("T")

# %%
df = df.drop(['T'], axis=1)

# %%
df = df.drop(['U'], axis=1)

# %%
G_plot("Y")

# %%
df = df.drop(['Y'], axis=1)

# %%
G_plot("Z")

# %%
df = df.drop(['Z'], axis=1)

# %%
G_plot("AA")

# %%
df = df.drop(['AA'], axis=1)

# %%
G_plot("BB")

# %%
df = df.drop(['BB'], axis=1)

# %%
G_plot("CC")

# %%
df = df.drop(['CC'], axis=1)

# %%
df.head(1)
# Out:
#        Time       E    EE      FF  Month    Year        Date
# 0  00:00:00  50.167  Grid  37.387   10.0  2022.0  2022-10-24

# %%
df.isnull().sum()
# Out:
# Time     200
# E        435
# EE       435
# FF       435
# Month    200
# Year     200
# Date     200
# dtype: int64

# %%
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, fmt=".0f",cmap="YlOrRd_r")
plt.show()

# %%
df['Time']= df['Time'].astype(str)

# %%
df = df.drop(['EE'], axis=1)

# %%
df = df.drop(['E'], axis=1)

# %%
df.head(1)
# Out:
#        Time      FF  Month    Year        Date
# 0  00:00:00  37.387   10.0  2022.0  2022-10-24

# %% [markdown]
# A heat map was used to check the correlations to see which features will bw used for prediction and sensor E was the only feature that didnt gave a high correlation with the other features
#
# Bar graphs were used to check the min and max values of the features. features in which the min and max and similar should be dropped because it means that those values are around a particular range will not affect other factors.
#
# A line plot was plotted to see how the diffrent power sources and sensors  affected the system KW but the powers sources were around the same range for each sensor for the system KW which means that the sensors and the power sources dont affect systems KW so the power source and sensors colunms were dropped

# %%
df.isna().sum()
# Out:
# Time       0
# FF       435
# Month    200
# Year     200
# Date     200
# dtype: int64

# %%
df.shape
# Out:
# (47148, 5)

# %%
df["FF"]=df["FF"].fillna(df["FF"].mean())
df.isnull().sum()
# Out:
# Time       0
# FF         0
# Month    200
# Year     200
# Date     200
# dtype: int64

# %%
df=df.dropna(axis=0)
df.isnull().sum()
# Out:
# Time     0
# FF       0
# Month    0
# Year     0
# Date     0
# dtype: int64

# %%
df.shape
# Out:
# (46948, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of            Time      FF  Month    Year        Date
# 0      00:00:00  37.387   10.0  2022.0  2022-10-24
# 1      00:10:00  38.537   10.0  2022.0  2022-10-24
# 2      00:11:00  37.975   10.0  2022.0  2022-10-24
# 3      00:14:00  34.073   10.0  2022.0  2022-10-24
# 4      00:15:00  34.700   10.0  2022.0  2022-10-24
# ...         ...     ...    ...     ...         ...
# 46943  17:50:00  81.130    9.0  2022.0  2022-09-22
# 46944  17:51:00  82.982    9.0  2022.0  2022-09-22
# 46945  17:52:00  83.478    9.0  2022.0  2022-09-22
# 46946  17:53:00  80.948    9.0  2022.0  2022-09-22
# 46947  12:36:00  48.945    9.0  2022.0  2022-09-22
#
# [46948 rows x 5 columns]>

# %%
df.head()
# Out:
#        Time      FF  Month    Year        Date
# 0  00:00:00  37.387   10.0  2022.0  2022-10-24
# 1  00:10:00  38.537   10.0  2022.0  2022-10-24
# 2  00:11:00  37.975   10.0  2022.0  2022-10-24
# 3  00:14:00  34.073   10.0  2022.0  2022-10-24
# 4  00:15:00  34.700   10.0  2022.0  2022-10-24

# %%
df=df[1::30]
df.head
#FIRST 30 then 60
# Out:
# <bound method NDFrame.head of            Time       FF  Month    Year        Date
# 1      00:10:00   38.537   10.0  2022.0  2022-10-24
# 31     00:50:00   39.243   10.0  2022.0  2022-10-24
# 61     01:21:00   40.012   10.0  2022.0  2022-10-24
# 91     06:00:00  112.732   10.0  2022.0  2022-10-24
# 121    07:06:00  118.145   10.0  2022.0  2022-10-24
# ...         ...      ...    ...     ...         ...
# 46801  15:05:00   82.819    9.0  2022.0  2022-09-22
# 46831  15:37:00   83.105    9.0  2022.0  2022-09-22
# 46861  16:12:00   76.768    9.0  2022.0  2022-09-22
# 46891  16:50:00   80.183    9.0  2022.0  2022-09-22
# 46921  17:27:00   82.187    9.0  2022.0  2022-09-22
#
# [1565 rows x 5 columns]>

# %%
df=df[1::60]
df.head
# Out:
# <bound method NDFrame.head of            Time       FF  Month    Year        Date
# 31     00:50:00   39.243   10.0  2022.0  2022-10-24
# 1831   21:19:00   39.150   10.0  2022.0  2022-10-23
# 3631   20:07:00   93.484   10.0  2022.0  2022-10-22
# 5431   11:44:00  114.256   10.0  2022.0  2022-10-21
# 7231   03:10:00   42.583   10.0  2022.0  2022-10-19
# 9031   01:00:00   38.045   10.0  2022.0  2022-10-18
# 10831  21:19:00   57.322   10.0  2022.0  2022-10-17
# 12631  09:13:00   44.758   10.0  2022.0  2022-10-16
# 14431  05:19:00   37.169   10.0  2022.0  2022-10-14
# 16231  02:14:00   39.170   10.0  2022.0  2022-10-13
# 18031  11:54:00   96.149   10.0  2022.0  2022-10-12
# 19831  22:43:00   40.314   10.0  2022.0  2022-10-11
# 21631  21:06:00   40.949   10.0  2022.0  2022-10-09
# 23431  08:39:00   38.705   10.0  2022.0  2022-10-08
# 25231  13:51:00   87.864   10.0  2022.0  2022-10-07
# 27031  18:18:00  101.273   10.0  2022.0  2022-10-06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 31 to 46831
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    27 non-null     object
#  1   FF      27 non-null     float64
#  2   Month   27 non-null     float64
#  3   Year    27 non-null     float64
#  4   Date    27 non-null     object
# dtypes: float64(3), object(2)
# memory usage: 1.3+ KB

# %%
df['Time']= df['Time'].astype(str)
# Out:
# <ipython-input-146-dd956ff4fbe1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time']= df['Time'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 31 to 46831
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    27 non-null     object
#  1   FF      27 non-null     float64
#  2   Month   27 non-null     float64
#  3   Year    27 non-null     float64
#  4   Date    27 non-null     object
# dtypes: float64(3), object(2)
# memory usage: 1.3+ KB

# %%
fig = plt.figure()
ax1= fig.add_subplot(111)


sns.lineplot(x= df["Time"],y=df["FF"], data=df)
plt.title("Energy  vs Time ")
plt.xlabel("Time")
plt.grid(True, alpha=1)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# From the graph below we can see that the highest point of the system KW is around 11am close to noon time and is very low at 12am in the morning.
